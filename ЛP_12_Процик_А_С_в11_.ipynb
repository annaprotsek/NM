# %% [markdown]
# <a href="https://colab.research.google.com/github/annaprotsek/NM/blob/main/%D0%9BP_12_%D0%9F%D1%80%D0%BE%D1%86%D0%B8%D0%BA_%D0%90_%D0%A1_%D0%B211_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Завдання 3. Визначити інтеграм методом трапецій

# %%
#Обчислення інтегралу методом трапецій

from scipy import integrate
import numpy as np

# Задаємо функцію, яку необхідно інтегрувати
def f(x):
    #return 1 / x**2
    return 1/np.sqrt(0.5*x**2 + 1)

# Задаємо межі інтегрування та початкову кількість розбиттів
a, b, n = 3.2, 4, 10

# Обчислюємо значення інтегралу методом трапецій
def trapezoidal_rule(f, a, b, n):
    h = (b - a) / n
    sum = 0.5 * (f(a) + f(b))
    x = a

    for i in range(1, n):
        x += h
        sum += f(x)

    integral = h * sum

    return integral

# Виводимо результат методу трапецій
integral = trapezoidal_rule(f, a, b, n)
print("Trapetzia method result:", round(integral, 5))

# Перевірка за допомогою вбудованої функції
v, err = integrate.quad(f, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Trapetzia method result: 0.29336
# Check with SciPy quad method: 0.29335

# %% [markdown]
# Завдання 1. Метод прямокутників (правих, лівих і середніх)

# %%
#Обчислення інтеграла методом прямокутників
from scipy import integrate
import numpy as np

a, b, n = 2, 3.5, 10

h = (b - a) / n  # Крок

def f1(x):
    #return np.log10(x + 2) / x
    return 1 / np.sqrt(x - 1)

# Метод лівих прямокутників
def left_rec(f1, a, b):
    sum = 0
    for i in range(0, n):
        sum += f1(a + i * h)
    return sum * h

print("Left rectangle:", round(left_rec(f1, a, b), 5))

# Метод правих прямокутників
def right_rec(f1, a, b):
    sum = 0
    for i in range(1, n+1):
        sum += f1(a + i * h)
    return sum * h

print("Right rectangle:", round(right_rec(f1, a, b), 5))

# Метод середніх прямокутників
def aver_rec(f1, a, b):
    sum = 0
    for i in range(0, n):
        sum += f1(a + (i + 0.5) * h)
    return sum * h

print("Average rectangle:", round(aver_rec(f1, a, b), 5))

# Перевірка за допомогою функції scipy
v, err = integrate.quad(f1, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Left rectangle: 1.19054
# Right rectangle: 1.13541
# Average rectangle: 1.16193
# Check with SciPy quad method: 1.16228

# %% [markdown]
# Завдання 2. Метод Симпсона

# %%
#Обчислення інтеграла методом Симпсона
from scipy import integrate
import numpy as np

# Задаємо функцію, яку необхідно інтегрувати
def f(x):
    return np.sin(x) / (x + 1)

# Задаємо межі інтегрування та початкову кількість розбиттів
a, b, n = 0.18, 0.98, 8

h = (b - a) / n

# Обчислюємо значення інтегралу методом Симпсона
def simpson_rule(f, a, b, n):
    integr = f(a) + f(b)
    for i in range(1,n):
        k = a + i*h
        if i%2 == 0:
            integr += 2 * f(k)
        else:
            integr += 4 * f(k)
    integr *= h/3
    return integr


# Виводимо результат
print("Simpsone method:", round(simpson_rule(f, a, b, n), 6))

v,err = integrate.quad(f,a,b)#Перевірка
print("Check for the simpsone method= ",round(v, 6))
# Out:
# Simpsone method: 0.261376
# Check for the simpsone method=  0.261378
